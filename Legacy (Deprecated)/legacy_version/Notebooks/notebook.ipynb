# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('pitch_data.csv')
df.map(lambda x: x.strip() if isinstance(x, str) else x)
X = pd.get_dummies(df.drop('isStrike', axis=1))
Y = df['isStrike']

# %%
Y.value_counts()
# Out:
# isStrike
# True     830
# False    689
# Name: count, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
X_train.head()
# Out:
#       FirstX  FirstY     SecondX     SecondY      FinalX      FinalY  \
# 389    595.0   427.0  692.201294  538.908534  692.201294  538.908534
# 1444   598.0   404.0  625.161313  582.754393  625.161313  582.754393
# 313    595.0   427.0  533.036575  508.259211  533.036575  508.259211
# 280    701.0   449.0  722.673251  396.185065  722.673251  396.185065
# 518    588.0   423.0  586.743149  540.944523  578.766053  615.764496
#
#       Pitcher_Yamamoto  Pitcher_chrissale  Pitcher_jacobdegrom  \
# 389              False              False                 True
# 1444             False              False                False
# 313              False              False                 True
# 280              False               True                False
# 518               True              False                False
#
#       Pitcher_rokisasaki  PitchType_CB  PitchType_CH  PitchType_FF  \
# 389                False         False         False          True
# 1444                True         False         False          True
# 313                False         False         False          True
# 280                False         False         False          True
# 518                False         False         False         False
#
#       PitchType_FS  PitchType_SL  isHit_DOUBLE  isHit_HOMERUN  isHit_SINGLE  \
# 389          False         False         False          False         False
# 1444         False         False         False          False         False
# 313          False         False         False          False         False
# 280          False         False         False          False         False
# 518           True         False         False          False         False
#
#       isHit_TRIPLE  isHit_false
# 389          False         True
# 1444         False         True
# 313          False         True
# 280          False         True
# 518          False         True

# %%
Y_train.head()
# Out:
# 389      True
# 1444     True
# 313     False
# 280     False
# 518     False
# Name: isStrike, dtype: bool

# %% [markdown]
# 1. Import Dependencies.

# %%
from tensorflow.keras.layers import Dense, Input # type: ignore
from tensorflow.keras import Sequential # type: ignore
from tensorflow.keras.activations import sigmoid # type: ignore
from sklearn.metrics import accuracy_score

# %%
model = Sequential()
model.add(Dense(128, input_dim=len(X_train.columns), activation='relu'))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# /Users/xlq/Projects/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X_train, Y_train, epochs=1000, batch_size=32)
# Out:
# Epoch 1/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 480us/step - accuracy: 0.5332 - loss: 7.4874
# Epoch 2/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - accuracy: 0.5485 - loss: 1.7097
# Epoch 3/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - accuracy: 0.5645 - loss: 1.8509
# Epoch 4/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.5972 - loss: 1.1588
# Epoch 5/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - accuracy: 0.5566 - loss: 2.3518
# Epoch 6/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - accuracy: 0.6070 - loss: 1.1956
# Epoch 7/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - accuracy: 0.6119 - loss: 0.8948
# Epoch 8/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - accuracy: 0.5921 - loss: 1.6558
# Epoch 9/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - accuracy: 0.6045 - loss: 1.0583
# Epoch 10/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - accuracy: 0.5899 - loss: 1.2670
# Epoch 11/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - accuracy: 0.5765 - loss: 1.5108
# Epoch 12/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5919 - loss: 1.0943
# Epoch 13/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.5824 - loss: 1.1054
# Epoch 14/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - accuracy: 0.6452 - loss: 0.8363
# Epoch 15/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - accuracy: 0.6025 - loss: 1.1344
# Epoch 16/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - accuracy: 0.5661 - loss: 1.2443
# Epoch 17/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - accuracy: 0.6658 - loss: 0.8280
# Epoch 18/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - accuracy: 0.6006 - loss: 1.0494
# Epoch 19/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step - accuracy: 0.6029 - loss: 1.5285
# Epoch 20/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - accuracy: 0.6431 - loss: 0.8075
# Epoch 21/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - accuracy: 0.5619 - loss: 1.2950
# Epoch 22/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - accuracy: 0
1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - accuracy: 0.6888 - loss: 0.6162
# Epoch 81/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - accuracy: 0.6840 - loss: 0.6526
# Epoch 82/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - accuracy: 0.5786 - loss: 1.6316
# Epoch 83/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.6361 - loss: 0.8545
# Epoch 84/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - accuracy: 0.7120 - loss: 0.5815
# Epoch 85/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - accuracy: 0.6020 - loss: 1.0558
# Epoch 86/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.5526 - loss: 2.0419
# Epoch 87/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.5889 - loss: 1.4444
# Epoch 88/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - accuracy: 0.6048 - loss: 1.2430
# Epoch 89/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - accuracy: 0.6281 - loss: 1.4081
# Epoch 90/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - accuracy: 0.6933 - loss: 0.6656
# Epoch 91/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - accuracy: 0.6810 - loss: 0.6764
# Epoch 92/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - accuracy: 0.6507 - loss: 0.7747
# Epoch 93/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.6790 - loss: 0.7503
# Epoch 94/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - accuracy: 0.6762 - loss: 0.6852
# Epoch 95/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - accuracy: 0.6558 - loss: 0.8791
# Epoch 96/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - accuracy: 0.6034 - loss: 0.9717
# Epoch 97/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - accuracy: 0.6439 - loss: 0.9308
# Epoch 98/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - accuracy: 0.6887 - loss: 0.7184
# Epoch 99/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - accuracy: 0.6767 - loss: 0.6532
# Epoch 100/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - accuracy: 0.6192 - loss: 0.8759
# Epoch 101/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - accuracy: 0.6701 - loss: 0.8117
# Epoch 102/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - accuracy: 0.6755 - loss: 0.6818
# Epoch 103/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - accuracy: 0.6410 - loss: 0.9143
# Epoch 104/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - accuracy: 0.7370 - loss: 0.5780
# Epoch 105/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - accuracy: 0.7132 - loss: 0.6006
# Epoch 106/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step - accuracy: 0.7381 - loss: 0.5485
# Epoch 107/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - accuracy: 0.6533 - loss: 0.7926
# Epoch 108/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.6379 - loss: 0.9733
# Epoch 109/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - accuracy: 0.7107 - loss: 0.5830
# Epoch 110/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - accuracy: 0.6721 - loss: 0.6244
# Epoch 111/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - accuracy: 0.6514 - loss: 0.7687
# Epoch 112/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - accuracy: 0.6896 - loss: 0.6458
# Epoch 113/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.6822 - loss: 0.5670
# Epoch 114/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.6523 - loss: 0.6786
# Epoch 115/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - accuracy: 0.6848 - loss: 0.6335
# Epoch 116/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - accuracy: 0.6780 - loss: 0.6764
# Epoch 117/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - accuracy: 0.6118 - loss: 1.2276
# Epoch 118/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - accuracy: 0.7335 - loss: 0.5405
# Epoch 119/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.6974 - loss: 0.6260
# Epoch 120/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - accuracy: 0.7116 - loss: 0.6005
# Epoch 121/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - accuracy: 0.7382 - loss: 0.5817
# Epoch 122/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - accuracy: 0.7420 - loss: 0.5777
# Epoch 123/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - accuracy: 0.7253 - loss: 0.5580
# Epoch 124/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - accuracy: 0.6964 - loss: 0.5722
# Epoch 125/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - accuracy: 0.7664 - loss: 0.4711
# Epoch 126/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - accuracy: 0.7095 - loss: 0.6274
# Epoch 127/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - accuracy: 0.7231 - loss: 0.6080
# Epoch 128/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - accuracy: 0.6495 - loss: 0.8994
# Epoch 129/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - accuracy: 0.6201 - loss: 1.0421
# Epoch 130/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - accuracy: 0.6785 - loss: 0.6422
# Epoch 131/1000
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7500 - loss: 0.4617
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[379], line 1
# ----> 1 model.fit(X_train, Y_train, epochs=1000, batch_size=32)
#
# File ~/Projects/.venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/.venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File ~/Projects/.venv/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Projects/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Projects/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Projects/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Projects/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Projects/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Projects/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Projects/.venv/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/Projects/.venv/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
y_hat = model.predict(X_test)
y_hat = [1 if i > 0.5 else 0 for i in y_hat]  # convert to binary
accuracy_score(Y_test, y_hat)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 0.8089887640449438

# %%
model.save('strike_predictor.keras')
